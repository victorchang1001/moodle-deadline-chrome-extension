# %%
from bs4 import BeautifulSoup
import requests

url='https://wsdmoodle.waseda.jp/my/#'
req=requests.get(url)
content=req.text

# %%
print(content)
# Out:
# <!DOCTYPE html>
#
# <html  dir="ltr" lang="ja" xml:lang="ja">
# <head>
#     <title>Waseda Moodle: サイトにログインする</title>
#     <link rel="shortcut icon" href="https://wsdmoodle.waseda.jp/theme/image.php/boost/theme/1665771977/favicon" />
#     <meta name="apple-itunes-app" content="app-id=1553337282, app-argument=https://wsdmoodle.waseda.jp/login/index.php"/><link rel="manifest" href="https://wsdmoodle.waseda.jp/admin/tool/mobile/mobile.webmanifest.php" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="keywords" content="moodle, Waseda Moodle: サイトにログインする" />
# <link rel="stylesheet" type="text/css" href="https://wsdmoodle.waseda.jp/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" /><script id="firstthemesheet" type="text/css">/** Required in order to fix style inclusion problems in IE with YUI **/</script><link rel="stylesheet" type="text/css" href="https://wsdmoodle.waseda.jp/theme/styles.php/boost/1665771977_1660153273/all" />
# <script>
# ...
